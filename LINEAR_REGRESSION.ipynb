# %% [markdown]
# ### Linear regression to get information about it

# %% [markdown]
# ## Preparation

# %%
#dataFrame
import pandas as pd

#visualization
import matplotlib.pyplot as plt
import seaborn as sns
#sklearn
from sklearn.linear_model import LinearRegression

#split test data
from sklearn.model_selection import train_test_split

#utility
from scipy import stats
import numpy as np
import os
import time

# %%
#read dataset
df = pd.read_csv('kc_house_data.csv')
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ### Proses Cleaning data
# - drop duplicate data
# - drop null data
# - drop wrong format data

# %%
df.drop_duplicates(inplace = True)

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# ## check correlation before linear regression test

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# ### TRY LINIEAR REGRESSION BUT THE CORRELATION NOT PRETY
# ### GOOD WITH PRICE AND BEDROOMS IS 0.308350

# %%
fig = plt.figure(figsize=(10, 10))

nilaix = df['bedrooms']
nilaiy= df['price']

slope, intercept, r, p, std_err = stats.linregress(nilaix, nilaiy)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, nilaix))

plt.xlabel("Open price")
plt.ylabel("Close Price")
plt.scatter(nilaix,nilaiy)
plt.plot(nilaix,mymodel,color='r')
plt.show()

# %% [markdown]
# ### Bisa dilihat gambar di atas karena correlation tidak cukup baik maka gambar visual seperti di atas

# %%
# kita coba membuat split data train dan data test dengan menggunakan train test 40% dengan test 60%

# Reshape the 'price' feature
X = df['bedrooms'].values.reshape(-1, 1)
y = df['price']

# Split the data into training and testing sets
X_train, test_X, y_train, y_test = train_test_split(X, y, train_size=0.4, shuffle=False)

# Create and fit the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(test_X)

# %%
intercept =model.intercept_
coefficients = model.coef_

# %%
# Setelah model dilatih
coef = model.coef_
intercept = model.intercept_

# Menampilkan Intercept
print("Intercept:", intercept)

# Menampilkan Koefisien untuk Fitur Tunggal
print("Coefficient for 'price':", coefficients)
# Out:
# Intercept: 107776.99345424515
# Coefficient for 'price': [126946.23342464]

# %%
## evaluation with RMSE and MAE
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y_test, predictions, squared=False)
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 339018.33307364467

# %%
print("mean absolute error", mean_absolute_error(y_test,predictions))
# Out:
# mean absolute error 218266.89310413162

# %% [markdown]
# ### bisa dilihat dari hasil RMSE dan MAE terlihat sangat besar mencapai margin error
# - RMSE = 339018.33
# - MAE = 218266.89

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------BAGAIMANA JIKA KITA MEMPERBAIKI CORRELATIONNYA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
for x in df.index:
    if df.loc[x,'bedrooms'] == 7 or df.loc[x,'bedrooms'] == 8 or df.loc[x,'bedrooms'] == 9:
        df.drop(x,inplace = True)
        print("finish")
# Out:
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish
# finish

# %%
df['bedrooms'].value_counts()
# Out:
# 3    9824
# 4    6882
# 2    2760
# 5    1601
# 6     272
# 1     199
# Name: bedrooms, dtype: int64

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.015916  0.003587   0.006267    -0.011099 -0.131894
# price         -0.015916  1.000000  0.313660   0.525238     0.701420  0.089219
# bedrooms       0.003587  0.313660  1.000000   0.523694     0.593489  0.034784
# bathrooms      0.006267  0.525238  0.523694   1.000000     0.753961  0.087049
# sqft_living   -0.011099  0.701420  0.593489   0.753961     1.000000  0.171492
# sqft_lot      -0.131894  0.089219  0.034784   0.087049     0.171492  1.000000
# floors         0.018922  0.254571  0.183389   0.504160     0.352836 -0.005600
# waterfront    -0.002750  0.268686 -0.005870   0.064903     0.105457  0.021658
# view           0.011972  0.397829  0.083097   0.187219     0.283682  0.073493
# condition     -0.023572  0.034714  0.024420  -0.126383    -0.060307 -0.008665
# grade          0.008811  0.667328  0.374289   0.668838     0.765014  0.113522
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### TETAP TIDAK BANYAK PERUBAHAN KARENA MEMPUNYAI BANYAK FAKTOR PADA HARGA BUKAN HANYA DARI BEDROOMS SAJA
